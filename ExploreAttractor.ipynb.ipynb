# %%
from attractor import Attractor
import numpy as np
# %matplotlib inline

# %%
a=Attractor()

# %%
a.evolve()
# Out:
#            t         x         y             z
# 0      0.000  0.100000  0.000000  0.000000e+00
# 1      1.000  0.092717  0.022662  7.294576e-08
# 2      1.008  0.087798  0.043674  1.727704e-05
# 3      1.016  0.084938  0.063571  4.838528e-05
# 4      1.024  0.083897  0.082821  9.184189e-05
# 5      1.032  0.084489  0.101834  1.473501e-04
# 6      1.040  0.086578  0.120982  2.156212e-04
# 7      1.048  0.090064  0.140604  2.982393e-04
# 8      1.056  0.094884  0.161015  3.976123e-04
# 9      1.064  0.101005  0.182519  5.169890e-04
# 10     1.072  0.108421  0.205410  6.605346e-04
# 11     1.080  0.117149  0.229982  8.334574e-04
# 12     1.088  0.127231  0.256532  1.042187e-03
# 13     1.096  0.138727  0.285366  1.294611e-03
# 14     1.104  0.151719  0.316806  1.600365e-03
# 15     1.112  0.166310  0.351189  1.971211e-03
# 16     1.120  0.182621  0.388879  2.421482e-03
# 17     1.128  0.200794  0.430265  2.968643e-03
# 18     1.136  0.220994  0.475768  3.633971e-03
# ...

# %%
a.plotx()

# %%
a.ploty()

# %%
a.plotz()

# %%
a.plotxy()

# %%
a.plotyz()

# %%
a.plotzx()

# %%
a.plot3d()

# %%
b=Attractor(points=1000)

# %%
b.evolve()
# Out:
#          t             x             y             z
# 0     0.00  1.000000e-01  0.000000e+00  0.000000e+00
# 1     1.00  2.866598e-02  2.441737e-01  8.172396e-05
# 2     1.08  2.211488e-01  3.316275e-01  9.125667e-04
# 3     1.16  3.525892e-01  8.953020e-01  8.392602e-03
# 4     1.24  8.818108e-01  1.819911e+00  4.017779e-02
# 5     1.32  1.839718e+00  4.099167e+00  2.010413e-01
# 6     1.40  4.100873e+00  8.842462e+00  9.563874e-01
# 7     1.48  8.874174e+00  1.904396e+01  4.581813e+00
# 8     1.56  1.902248e+01  3.748962e+01  2.135004e+01
# 9     1.64  3.687539e+01  4.168366e+01  8.940306e+01
# 10    1.72  3.713205e+01 -1.997359e+02  1.958671e+02
# 11    1.80 -1.809678e+02 -6.178612e+02 -4.507838e+02
# 12    1.88 -6.749923e+02 -1.458792e+03  1.345175e+04
# 13    1.96 -1.159615e+04 -3.226964e+04  7.516172e+04
# 14    2.04  4.609557e+09 -1.760783e+14  3.792311e+14
# 15    2.12  1.154526e+49  4.013176e+77 -8.643435e+77
# 16    2.20          -inf           NaN           NaN
# ...

# %%
b.plotx()

# %%
b.ploty()

# %%
b.plotxy()

# %%
b.plot3d()

# %%
c=Attractor(points=100000)

# %%
c.evolve()
# Out:
#              t         x         y             z
# 0       0.0000  0.100000  0.000000  0.000000e+00
# 1       1.0000  0.099279  0.002243  7.180879e-11
# 2       1.0008  0.098581  0.004469  1.786194e-07
# 3       1.0016  0.097906  0.006680  5.316179e-07
# 4       1.0024  0.097254  0.008876  1.055238e-06
# 5       1.0032  0.096624  0.011057  1.745841e-06
# 6       1.0040  0.096016  0.013224  2.599973e-06
# 7       1.0048  0.095430  0.015377  3.614356e-06
# 8       1.0056  0.094865  0.017517  4.785892e-06
# 9       1.0064  0.094321  0.019645  6.111646e-06
# 10      1.0072  0.093799  0.021760  7.588853e-06
# 11      1.0080  0.093297  0.023864  9.214905e-06
# 12      1.0088  0.092815  0.025956  1.098735e-05
# 13      1.0096  0.092354  0.028038  1.290389e-05
# 14      1.0104  0.091913  0.030109  1.496237e-05
# 15      1.0112  0.091491  0.032170  1.716078e-05
# 16      1.0120  0.091090  0.034222  1.949726e-05
# 17      1.0128  0.090707  0.036265  2.197008e-05
# ...

# %%
c.plotx()

# %%
c.ploty()

# %%
c.plotz()

# %%
c.plotxy()

# %%
c.plotzx()

# %%
c.plotyz()

# %%
c.plot3d()

# %%
d=Attractor()
d.evolve(np.array([0.0, 0.1, 0.0]))
# Out:
#            t         x         y             z
# 0      0.000  0.000000  0.100000  0.000000e+00
# 1      1.000  0.008094  0.100001  2.605956e-08
# 2      1.008  0.015598  0.101836  6.655006e-06
# 3      1.016  0.022704  0.105372  1.955175e-05
# 4      1.024  0.029579  0.110518  3.883599e-05
# 5      1.032  0.036369  0.117222  6.501568e-05
# 6      1.040  0.043208  0.125465  9.895910e-05
# 7      1.048  0.050216  0.135258  1.418967e-04
# 8      1.056  0.057506  0.146639  1.954479e-04
# 9      1.064  0.065186  0.159672  2.616701e-04
# 10     1.072  0.073361  0.174446  3.431299e-04
# 11     1.080  0.082137  0.191072  4.429975e-04
# 12     1.088  0.091619  0.209688  5.651667e-04
# 13     1.096  0.101918  0.230452  7.144053e-04
# 14     1.104  0.113147  0.253550  8.965395e-04
# 15     1.112  0.125427  0.279193  1.118682e-03
# 16     1.120  0.138889  0.307619  1.389510e-03
# 17     1.128  0.153670  0.339095  1.719603e-03
# 18     1.136  0.169923  0.373921  2.121860e-03
# ...

# %%
d.plotx()

# %%
d.ploty()

# %%
d.plotx()

# %%
d.plotxy()

# %%
d.plotzx()

# %%
d.plotyz()

# %%
d.plot3d()

# %%
e=Attractor()
e.evolve(np.array([0.0, 0.0, 0.1]))
# Out:
#            t  x  y             z
# 0      0.000  0  0  1.000000e-01
# 1      1.000  0  0  9.864432e-02
# 2      1.008  0  0  9.730703e-02
# 3      1.016  0  0  9.598786e-02
# 4      1.024  0  0  9.468657e-02
# 5      1.032  0  0  9.340293e-02
# 6      1.040  0  0  9.213669e-02
# 7      1.048  0  0  9.088761e-02
# 8      1.056  0  0  8.965547e-02
# 9      1.064  0  0  8.844003e-02
# 10     1.072  0  0  8.724107e-02
# 11     1.080  0  0  8.605836e-02
# 12     1.088  0  0  8.489169e-02
# 13     1.096  0  0  8.374083e-02
# 14     1.104  0  0  8.260558e-02
# 15     1.112  0  0  8.148571e-02
# 16     1.120  0  0  8.038103e-02
# 17     1.128  0  0  7.929132e-02
# 18     1.136  0  0  7.821639e-02
# 19     1.144  0  0  7.715603e-02
# 20     1.152  0  0  7.611004e-02
# 21     1.160  0  0  7.507824e-02
# 22     1.168  0  0  7.406042e-02
# 23     1.176  0  0  7.305640e-02
# 24     1.184  0  0  7.206599e-02
# 25     1.192  0  0  7.108901e-02
# 26     1.200  0  0  7.012527e-02
# ...

# %%
e.plotx()

# %%
e.ploty()

# %%
e.plotz()

# %%
e.plotxy()

# %%
e.plot3d()

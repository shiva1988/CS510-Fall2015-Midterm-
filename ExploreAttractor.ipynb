# %% [markdown]
# # Midterm project-Plots
# ## Shiva Barzili

# %%
from attractor import Attractor
import numpy as np
# %matplotlib inline

# %%
a=Attractor()

# %% [markdown]
# I just here change the order and plot for order=1 ,order=2,order=4.the higher degree of order we use,the more accurate result we get.            .Using 3 trial steps produces a 4th order method, which is usually a sufficient compromise between extra computation and precision.

# %%
a.evolve(order=1)
# Out:
#               t          x         y          z
# 0      0.000000   0.100000  0.000000   0.000000
# 1      0.008001   0.092000  0.022400   0.000000
# 2      0.016002   0.086432  0.042829   0.000016
# 3      0.024002   0.082944  0.061847   0.000046
# 4      0.032003   0.081256  0.079932   0.000086
# 5      0.040004   0.081150  0.097493   0.000136
# 6      0.048005   0.082458  0.114891   0.000196
# 7      0.056006   0.085052  0.132442   0.000268
# 8      0.064006   0.088843  0.150434   0.000352
# 9      0.072007   0.093771  0.169131   0.000452
# 10     0.080008   0.099799  0.188783   0.000569
# 11     0.088009   0.106918  0.209627   0.000708
# 12     0.096010   0.115135  0.231899   0.000872
# 13     0.104010   0.124476  0.255833   0.001067
# 14     0.112011   0.134985  0.281668   0.001299
# 15     0.120012   0.146719  0.309650   0.001575
# 16     0.128013   0.159754  0.340036   0.001905
# 17     0.136014   0.174176  0.373098   0.002299
# 18     0.144014   0.190090  0.409126   0.002770
# ...

# %%
a.plotx()

# %%
a.ploty()

# %%
a.plotz()

# %%
a.plotxy()

# %%
a.plotyz()

# %%
a.plotzx()

# %%
a.plot3d()

# %%
a.evolve(order=2)
# Out:
#               t          x          y          z
# 0      0.000000   0.100000   0.000000   0.000000
# 1      0.008001   0.086432   0.042829   0.000017
# 2      0.016002   0.081256   0.079932   0.000087
# 3      0.024002   0.082458   0.114891   0.000197
# 4      0.032003   0.088843   0.150434   0.000353
# 5      0.040004   0.099799   0.188783   0.000569
# 6      0.048005   0.115135   0.231899   0.000871
# 7      0.056006   0.134985   0.281668   0.001298
# 8      0.064006   0.159754   0.340036   0.001903
# 9      0.072007   0.190090   0.409126   0.002766
# 10     0.080008   0.226878   0.491341   0.004000
# 11     0.088009   0.271250   0.589468   0.005768
# 12     0.096010   0.324611   0.706782   0.008303
# 13     0.104010   0.388675   0.847162   0.011939
# 14     0.112011   0.465519   1.015223   0.017157
# 15     0.120012   0.557641   1.216466   0.024646
# 16     0.128013   0.668042   1.457458   0.035394
# 17     0.136014   0.800320   1.746030   0.050819
# ...

# %%
a.plotx()

# %%
a.ploty()

# %%
a.plotz()

# %%
a.plotxy()

# %%
a.plotyz()

# %%
a.plotzx()

# %%
a.plot3d()

# %%
a.evolve(order=4)
# Out:
#               t          x          y          z
# 0      0.000000   0.100000   0.000000   0.000000
# 1      0.008001   0.092379   0.022115   0.000003
# 2      0.016002   0.087085   0.042431   0.000021
# 3      0.024002   0.083800   0.061472   0.000052
# 4      0.032003   0.082269   0.079689   0.000094
# 5      0.040004   0.082293   0.097474   0.000146
# 6      0.048005   0.083720   0.115173   0.000209
# 7      0.056006   0.086436   0.133096   0.000284
# 8      0.064006   0.090361   0.151529   0.000373
# 9      0.072007   0.095442   0.170735   0.000478
# 10     0.080008   0.101654   0.190966   0.000601
# 11     0.088009   0.108989   0.212467   0.000748
# 12     0.096010   0.117464   0.235479   0.000923
# 13     0.104010   0.127111   0.260248   0.001131
# 14     0.112011   0.137978   0.287023   0.001379
# 15     0.120012   0.150132   0.316063   0.001676
# 16     0.128013   0.163654   0.347642   0.002031
# 17     0.136014   0.178639   0.382048   0.002456
# ...

# %%
a.plotx()

# %%
a.ploty()

# %%
a.plotz()

# %%
a.plotxy()

# %%
a.plotyz()

# %%
a.plotzx()

# %%
a.plot3d()

# %% [markdown]
# we want to be sure our datas will be saved.

# %%
a.save()

# %% [markdown]
# when we increse the time step size to points=100000,new plots dont change a lot,just we will not get the same clarity(resolution).but it gives us significantly more spots to work on.

# %%
a=Attractor(points=100000)

# %%
a.evolve(order=1)
# Out:
#              t         x         y             z
# 0       0.0000  0.100000  0.000000  0.000000e+00
# 1       0.0008  0.099200  0.002240  0.000000e+00
# 2       0.0016  0.098424  0.004460  1.777664e-07
# 3       0.0024  0.097673  0.006661  5.285878e-07
# 4       0.0032  0.096945  0.008844  1.047971e-06
# 5       0.0040  0.096240  0.011008  1.731634e-06
# 6       0.0048  0.095558  0.013155  2.575500e-06
# 7       0.0056  0.094899  0.015285  3.575687e-06
# 8       0.0064  0.094262  0.017399  4.728509e-06
# 9       0.0072  0.093647  0.019496  6.030460e-06
# 10      0.0080  0.093054  0.021579  7.478218e-06
# 11      0.0088  0.092482  0.023646  9.068631e-06
# 12      0.0096  0.091931  0.025698  1.079872e-05
# 13      0.0104  0.091401  0.027737  1.266566e-05
# 14      0.0112  0.090892  0.029762  1.466680e-05
# 15      0.0120  0.090403  0.031774  1.679963e-05
# 16      0.0128  0.089934  0.033774  1.906179e-05
# 17      0.0136  0.089485  0.035761  2.145107e-05
# ...

# %%
a.plotx()

# %%
a.ploty()

# %%
a.plotxy()

# %% [markdown]
# a.plot3d()

# %% [markdown]
# here we just change the initial conditions,as we can observe below,any small change in initial conditions will result in significant changes in our plot.

# %%
a=Attractor(points=10000)
a.evolve(0.0, 0.0, 0.0)
# Out:
#               t  x  y  z
# 0      0.000000  0  0  0
# 1      0.008001  0  0  0
# 2      0.016002  0  0  0
# 3      0.024002  0  0  0
# 4      0.032003  0  0  0
# 5      0.040004  0  0  0
# 6      0.048005  0  0  0
# 7      0.056006  0  0  0
# 8      0.064006  0  0  0
# 9      0.072007  0  0  0
# 10     0.080008  0  0  0
# 11     0.088009  0  0  0
# 12     0.096010  0  0  0
# 13     0.104010  0  0  0
# 14     0.112011  0  0  0
# 15     0.120012  0  0  0
# 16     0.128013  0  0  0
# 17     0.136014  0  0  0
# 18     0.144014  0  0  0
# 19     0.152015  0  0  0
# 20     0.160016  0  0  0
# 21     0.168017  0  0  0
# 22     0.176018  0  0  0
# 23     0.184018  0  0  0
# 24     0.192019  0  0  0
# 25     0.200020  0  0  0
# 26     0.208021  0  0  0
# 27     0.216022  0  0  0
# 28     0.224022  0  0  0
# 29     0.232023  0  0  0
# ...         ... .. .. ..
# 9970  79.767977  0  0  0
# 9971  79.775978  0  0  0
# 9972  79.783978  0  0  0
# 9973  79.791979  0  0  0
# 9974  79.799980  0  0  0
# ...

# %%
a.plotx()

# %%
a.ploty()

# %%
a.plotz()

# %%
a.plotxy()

# %%
a.plotyz()

# %%
a.plotzx()

# %%
a.plot3d()

# %%
a.evolve(0.0, 0.0, 0.1)
# Out:
#               t  x  y             z
# 0      0.000000  0  0  1.000000e-01
# 1      0.008001  0  0  9.787417e-02
# 2      0.016002  0  0  9.579354e-02
# 3      0.024002  0  0  9.375713e-02
# 4      0.032003  0  0  9.176401e-02
# 5      0.040004  0  0  8.981327e-02
# 6      0.048005  0  0  8.790399e-02
# 7      0.056006  0  0  8.603530e-02
# 8      0.064006  0  0  8.420634e-02
# 9      0.072007  0  0  8.241626e-02
# 10     0.080008  0  0  8.066423e-02
# 11     0.088009  0  0  7.894945e-02
# 12     0.096010  0  0  7.727112e-02
# 13     0.104010  0  0  7.562847e-02
# 14     0.112011  0  0  7.402074e-02
# 15     0.120012  0  0  7.244718e-02
# 16     0.128013  0  0  7.090708e-02
# 17     0.136014  0  0  6.939972e-02
# 18     0.144014  0  0  6.792440e-02
# 19     0.152015  0  0  6.648044e-02
# 20     0.160016  0  0  6.506718e-02
# 21     0.168017  0  0  6.368397e-02
# 22     0.176018  0  0  6.233015e-02
# 23     0.184018  0  0  6.100512e-02
# 24     0.192019  0  0  5.970826e-02
# ...

# %%
a.plotx()

# %%
a.ploty()

# %%
a.plotz()

# %%
a.plotxy()

# %%
a.plotyz()

# %%
a.plotzx()

# %%
a.plot3d()
